# %% [markdown]
# # **02477 Bayesian Machine Learning Exam 2024**

# %% [markdown]
# ### **Part 1: Linear Gaussian systems**

# %% [markdown]
# ##### **Question 1.1: Determine the conditional distribution of $x_1$ given $x_2$.**

# %% [markdown]
# ##### **Question 1.2: Determine the marginal distribution of $x_3$, i.e. $p(x_3)$.**

# %% [markdown]
# ##### **Question 1.3: Determine the conditional distribution of $x_3$ given $x_1$.**

# %% [markdown]
# ### **Part 2: Gaussian process regression**

# %% [markdown]
# ##### **Question 2.1: Determine the likelihood for the regression model in eq. $(4)$.**

# %% [markdown]
# ##### **Question 2.2: Determine the analytical prior predictive distribution $p(y^*|x^*=1)$ for $y^* = y(x^*)$.**

# %% [markdown]
# ##### **Question 2.3: Determine the analytical posterior predictive distribution $p(y^*|y, x^*=227)$ for $y^* = y(x^*)$.**

# %% [markdown]
# ##### **Question 2.4: Determine the analytical expression for the marginal likelihood $p(y|\kappa, \ell, \sigma)$ and compute the numerical value of $\log p(y|\kappa, \ell, \sigma)$.**

# %% [markdown]
# ##### **Question 2.5: Determine the analytical posterior distribution $p(f^*|y, x^*=1)$ for $f^*=f(x^*)$ as well as the analytical posterior predictive distribution for $p(y^*|y,x^*=1)$ for $y^* = y(x^*)$.**

# %% [markdown]
# ##### **Question 2.6: Determine whether $k_2$ is a stationary kernel and determine whether $k_2$ is an isotropic kernel.**

# %% [markdown]
# ##### **Question 2.7: Compute the prior covariance between $f=[f(x_1), f(x_2), \dots, f(x_8)]$ and $f^*=f(x^*)$ for $x^*=-1$ for $c_1 = c_2 = 1$ and $\ell = \frac{1}{\sqrt{2}}$.**

# %% [markdown]
# ### **Part 3: Binary classification**

# %% [markdown]
# ##### **Question 3.1: Suppose you suspect a bug in the code for computing the MAP estimator. Explain how you could verify that $\hat{w}_{\text{MAP}}$ is indeed the correct MAP estimator.**

# %% [markdown]
# ##### **Question 3.2: Determine the posterior predictive distribution for $p(y^*|y, x^* = −3) using the plug-in approximation based on the MAP-estimator.**

# %% [markdown]
# ##### **Question 3.3: Use the Gaussian approximation to compute a 90% posterior credibility interval for $w_0$.**

# %% [markdown]
# ##### **Question 3.4: Use the Gaussian approximation to compute the approximate posterior distribu-tion $p(f^∗|y, x^∗ = −3)$ and the approximate posterior predictive distribution for $p(y^∗|y, x^∗ = −3)$ using the probit approximation.**

# %% [markdown]
# ##### **Question 3.5: Compute the expected utility for each decision $\hat{y} \in \{0, 1\}$ and determine the optimal decision wrt. the utility matrix above.**

# %% [markdown]
# ### **Part 4: Variational inference**

# %% [markdown]
# ##### **Question 4.1: Determine the analytical expression of the entropy of $q(w_1, w_2)$ and evaluate it for the initial variational parameter values given above.**

# %% [markdown]
# ##### **Question 4.2: Determine the analytical expression for the expected log likelihood and evaluate it for the initial variational parameter values given above.**

# %% [markdown]
# ##### **Question 4.3: Determine the approximate posterior covariance between $w_1$ and $w_2$ with respect to the optimal approximation $q^*$.**

# %% [markdown]
# ### **Part 5: Markov Chain Monte Carlo**

# %% [markdown]
# ##### **Question 5.1: Plot the contours of the posterior density for the ranges $z_1 \in [−2, 2]$ and $z_2 \in [−1, 3]$ with 100 equidistant points for both $z_1$ and $z_2$.**

# %% [markdown]
# ##### **Question 5.2: Run a single MCMC chain using the Metropolis algorithm for 104 iterations using the proposal distribution given above. Initialize the chain at $(z_1, z_2) = (0, 1.5)$. Discard $10%$ of the samples as warm up. Plot the resulting traces for both parameters.**

# %% [markdown]
# ##### **Question 5.3: Estimate the posterior mean of $\sin(z_1z_2)$ using the samples.**

# %% [markdown]
# ##### **Question 5.4: Estimate the posterior probability that $p(z_1 > z_2 | \mathcal{D})$ using the samples.**
