# %% [markdown]
# # **Index file | 02477 Exam preperation**

# %% [markdown]
# ___

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# # **Cheat sheets**
#
# </div>

# %% [markdown]
# ### [Python codes cheat sheet](02477_exam_codebook.ipynb)

# %% [markdown]
# ### [Missing pieces, search here if you are lost](02477_missing_pieces.ipynb)

# %% [markdown]
# ### [Formula cheat sheet](02477_cheat_sheet.ipynb)

# %% [markdown]
# ### [Common pitfalls](PART_3_EXTRAS_02477.ipynb)

# %% [markdown]
# ### [Code notebook for derivation guides](code_on_paper_02477.ipynb)

# %% [markdown]
# ### [Code scripts for "type opgaver"](tasks_scripts.ipynb)

# %% [markdown]
# ### [Guides on how to derive key results](derivations_02477.ipynb)

# %% [markdown]
# ### [Course notes (week 1 to 6)](PART_1_cheat_sheet_02477.ipynb)

# %% [markdown]
# ### [Course notes (week 7 to 12)](PART_2_cheat_sheet_02477.ipynb)

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# # **Course notebook solutions**
#
# </div>

# %% [markdown]
# ### **Week 1:**
#
# [Week 1 notebook](../notebooks/ex1_handout.ipynb)
#
# [Slides 1](../slides/lecture1_handout.pdf)

# %% [markdown]
# **EX 1 | PART 1** | posterior predictive distribution, marginal likelihood (evidence), plug-in approximation, Dirac delta, sifting property, non-conjugate models, grid approximation, curse of dimensionality, 2D grid approximation
#
# **EX 1 | PART 2** | linear regression, basis functions, design matrix, MLE (normal equations), MAP estimator, ridge regression, regularised least squares, Gaussian prior, precision ($\alpha$, $\beta$), generative vs discriminative classification, logistic regression, sigmoid, softmax, multi-class, Bayesian logistic regression, log-joint
#
# **EX 1 | PART 3** | Bayesian linear regression, posterior parameters ($m$, $S$), linear Gaussian systems, posterior predictive (regression + classification), probit approximation, evidence approximation, marginal likelihood for model selection
#
# **EX 1 | PART 4** | Bayesian classification, Laplace approximation (MAP + Hessian + Gaussian fit), logistic regression Hessian, Laplace marginal likelihood, posterior predictive for classification, sampling vs probit
#
# **EX 1 | PART 5** | Gaussian processes, mean function, covariance function (kernel), squared exponential (RBF), Matérn, linear kernel, ARD, stationary/isotropic, hyperparameters ($\kappa$, $\ell$), GP regression, joint distribution, posterior predictive ($f^*$ and $y^*$), Gaussian conditioning formula, marginal likelihood for hyperparameter selection, Cholesky decomposition, $O(N^3)$ complexity
#
# **EX 1 | PART 6** | GP classification, intractable posterior, Laplace approximation for GPs, gradient/Hessian of log-joint ($\Lambda$ matrix), posterior predictive for GP classification, probit approximation ($\Phi$ formula), valid kernel construction (sum/product/scaling), Mercer's theorem, feature spaces, neural networks as basis functions

# %% [markdown]
# ### **Week 2:**
#
# [Week 2 notebook](../notebooks/ex2_handout.ipynb)
#
# [Slides 2](../slides/lecture2_handout.pdf)

# %% [markdown]
# **EX 2 | PART 1** | posterior predictive distribution $p(y^*|\mathbf{y}, \mathbf{x}, x^*)$, logistic regression model, binomial likelihood $\text{Bin}(y_i|N, \theta_i)$, conditional independence, product rule, joint distribution, sigmoid $\sigma(x) = (1+e^{-x})^{-1}$, linear component $f(x) = \alpha + \beta x$, failure probability $\theta(x) = \sigma(\alpha + \beta x)$, Gaussian prior $\mathcal{N}(\alpha|0,\sigma^2_\alpha)\mathcal{N}(\beta|0,\sigma^2_\beta)$, marginalization via sum rule, posterior $\propto$ joint
#
# **EX 2 | PART 2** | log-prior, log-likelihood, log-joint, contour plots, posterior proportional to joint (normalizing constant argument), effect of prior variance $\sigma^2_\alpha$ and $\sigma^2_\beta$, flat prior (large variance $\to$ MLE $\approx$ MAP), effect of data size on posterior width, credibility interval for $\beta < 0$, prior variance controls regularization strength
#
# **EX 2 | PART 3** | plug-in approximation $\hat{\theta}(x) = \sigma(\hat{\alpha} + \hat{\beta}x)$, MLE estimator $\hat{\alpha}_\text{MLE}, \hat{\beta}_\text{MLE}$, MAP estimator $\hat{\alpha}_\text{MAP}, \hat{\beta}_\text{MAP}$, grid argmax, point estimate predictions, overconfidence of plug-in
#
# **EX 2 | PART 4** | 2D grid approximation $q(\alpha, \beta)$, normalization constant $Z = \sum_{ij}\tilde{\pi}_{ij}$, grid weights $\pi_{ij}$, log-sum-exp stability trick, marginal posteriors $q(\alpha_i) = \sum_j \pi_{ij}$ and $q(\beta_j) = \sum_i \pi_{ij}$, discrete distribution (mean $\mathbb{E}[X] = \sum_i x_i p_i$, variance $\mathbb{V}[X] = \sum_i(x_i - \mathbb{E}[X])^2 p_i$), CDF, quantile, 95% credibility interval, posterior probability $p(\beta < 0)$
#
# **EX 2 | PART 5** | posterior predictive via weighted average $\sum_{ij} p(y^*|x^*, \alpha_i, \beta_j)\pi_{ij}$, plug-in vs full Bayesian comparison, overconfidence in data-sparse regions, posterior samples of $f(x)$ and $\theta(x)$, prior vs posterior predictive visualization, uncertainty propagation from $(\alpha, \beta)$ to predictions, probability of at least one failure $1-(1-\theta)^N$, posterior mean and 95% credibility band

# %% [markdown]
# ### **Week 3:**
#
# [Week 3 notebook](../notebooks/ex3_handout.ipynb)
#
# [Slides 3](../slides/lecture3_handout.pdf)

# %% [markdown]
# **EX 3 | PART 1** | design matrix $\mathbf{\Phi}$, basis functions $\phi(x_n)$, MLE normal equations $\hat{\mathbf{w}}_\text{MLE} = (\mathbf{\Phi}^T\mathbf{\Phi})^{-1}\mathbf{\Phi}^T\mathbf{y}$, Gaussian prior $\mathcal{N}(\mathbf{w}|\mathbf{m}_0, \mathbf{S}_0)$, isotropic prior $\mathbf{S}_0 = \alpha^{-1}\mathbf{I}$, noise precision $\beta = 1/\sigma^2$, posterior covariance $\mathbf{S} = (\mathbf{S}_0^{-1} + \beta\mathbf{\Phi}^T\mathbf{\Phi})^{-1}$, posterior mean $\mathbf{m} = \beta\mathbf{S}\mathbf{\Phi}^T\mathbf{y}$, MAP vs posterior mean vs MLE, effect of $\alpha$ (prior precision controls regularization) and $\beta$ (noise precision controls data trust), large $\alpha$ shrinks weights to zero, small $\beta$ ignores data
#
# **EX 3 | PART 2** | linear Gaussian system, Murphy eq. (3.33)–(3.38), posterior via pattern matching, marginal likelihood $p(\mathbf{y}) = \mathcal{N}(\mathbf{y}|\mathbf{0}, \alpha^{-1}\mathbf{\Phi}\mathbf{\Phi}^T + \beta^{-1}\mathbf{I})$, joint distribution $p(\mathbf{w}, \mathbf{y})$, $\alpha \to 0$ gives MLE (flat prior limit), $\beta \to 0$ gives prior (infinite noise limit)
#
# **EX 3 | PART 3** | implementing posterior $(\mathbf{m}, \mathbf{S})$, 95% credibility interval via $\mu \pm 1.96\sigma$, posterior mean as point estimate, posterior variance for uncertainty quantification
#
# **EX 3 | PART 4** | posterior distribution of $f^* $: $p(f^*|\mathbf{y}, x^*) = \mathcal{N}(f^*|\phi_*^T\mathbf{m},\, \phi_*^T\mathbf{S}\phi_*)$, posterior predictive distribution of $y^*$: $p(y^*|\mathbf{y}, x^*) = \mathcal{N}(y^*|\phi_*^T\mathbf{m},\, \phi_*^T\mathbf{S}\phi_* + \beta^{-1})$, epistemic variance $\phi_*^T\mathbf{S}\phi_*$ decreases with data, aleatoric variance $\beta^{-1}$ is irreducible, variance decomposition $\mathbb{V}[y^*] = \mathbb{V}[f^*] + \mathbb{V}[\epsilon]$, prior variance of $f(x^*)$ is $\alpha^{-1}(1 + (x^*)^2)$ (minimal at $x^*=0$), posterior samples of $\mathbf{w}$ as function samples, sequential update (posterior narrows with more data)
#
# **EX 3 | PART 5** | airline passengers dataset, log-transform of response, train/test split, evidence approximation $\alpha^*, \beta^* = \arg\max_{\alpha,\beta} \ln p(\mathbf{y}|\alpha,\beta)$, type II maximum likelihood, ELPD $= \frac{1}{M}\sum_i \ln p(y^*_i|\mathbf{y}, x^*_i)$, model selection via marginal likelihood vs cross-validation, polynomial basis functions, seasonal basis (cosine), optimizing $\tilde{\alpha} = \log\alpha$ for positivity, log-normal distribution $P(x) = \exp[y(x)]$ with mean $e^{m+v/2}$ and variance $(e^v - 1)e^{2m+v}$, sampling-based vs analytical predictive for transformed output, $p(f^*|\mathbf{y},x^*)$ vs $p(y^*|\mathbf{y},x^*)$ for credibility intervals (use $y^*$ for actual predictions)

# %% [markdown]
# ### **Week 4:**
#
# [Week 4 notebook](../notebooks/ex4_handout.ipynb)
#
# [Slides 4](../slides/lecture4_handout.pdf)

# %% [markdown]
# **EX 4 | PART 1** | generative classifier, class-conditional distribution $p(\mathbf{x}|y=k) = \mathcal{N}(\mathbf{x}|\mathbf{m}_k, \mathbf{S}_k)$, prior class probability $\pi_k = p(y=k)$, marginal data distribution $p(\mathbf{x}) = \sum_k \pi_k \mathcal{N}(\mathbf{x}|\mathbf{m}_k, \mathbf{S}_k)$, posterior class probability $p(y=k|\mathbf{x}) = p(\mathbf{x}|y=k)p(y=k)/p(\mathbf{x})$, MLE estimates for $\mathbf{m}_k$ and $\mathbf{S}_k$, decision rule $\hat{y} = \arg\max_k p(y=k|\mathbf{x})$, accuracy, ELPD $= \frac{1}{M}\sum_i \log \text{Ber}(y^*_i|p^*_i)$, generative vs discriminative comparison, PCA for dimensionality reduction
#
# **EX 4 | PART 2** | Laplace approximation, second-order Taylor expansion of $\log p(\theta, y)$ around $\theta_\text{MAP}$, $q(\theta) = \mathcal{N}(\theta|\theta_\text{MAP}, A^{-1})$ where $A = -\nabla^2 \log p(y,\theta)|_{\theta_\text{MAP}}$, Beta-binomial log joint $(\alpha_0+y-1)\ln\theta + (\beta_0+N-y-1)\ln(1-\theta)$, gradient and Hessian of log joint, MAP via numerical optimization (scipy minimize), quality of Laplace vs true Beta posterior, domain respect issue ($\theta \in [0,1]$), approximation improves with larger $N$
#
# **EX 4 | PART 3** | Bayesian logistic regression, log joint $\sum_n [y_n \log\sigma(f_n) + (1-y_n)\log(1-\sigma(f_n))] - \frac{\alpha}{2}\mathbf{w}^T\mathbf{w}$, gradient $\nabla_\mathbf{w} \log p(\mathbf{y},\mathbf{w}) = -\sum_n[\sigma(f_n)-y_n]\mathbf{x}_n - \alpha\mathbf{w}$, Hessian $\mathcal{H}(\mathbf{w}) = -\mathbf{X}^T\mathbf{S}\mathbf{X} - \alpha\mathbf{I}$ where $S_{nn} = \sigma(f_n)(1-\sigma(f_n))$, Kronecker delta $\delta_{ij}$, feature transformations for non-linear decision boundaries, MAP via gradient-based optimization, non-conjugate posterior
#
# **EX 4 | PART 4** | Laplace approximation for logistic regression, posterior mean $\mathbf{m} = \mathbf{w}_\text{MAP}$, posterior covariance $\mathbf{S} = (-\mathcal{H}(\mathbf{w}_\text{MAP}))^{-1}$, posterior samples from $q(\mathbf{w}) = \mathcal{N}(\mathbf{w}|\mathbf{m}, \mathbf{S})$, visualizing samples vs posterior contours
#
# **EX 4 | PART 5** | posterior predictive $p(y^*=1|\mathbf{y},\mathbf{x}^*) = \int \sigma(f^*)\mathcal{N}(f^*|m^*, v^*)df^*$, latent $m^* = \mathbf{m}^T\mathbf{x}^*$ and $v^* = (\mathbf{x}^*)^T\mathbf{S}\mathbf{x}^*$, plug-in approximation $\approx \sigma(m^*)$, probit approximation $\approx \Phi\!\left(\frac{m^*}{\sqrt{8/\pi + v^*}}\right)$, Monte Carlo estimator $\approx \frac{1}{S}\sum_i \sigma(f^*_{(i)})$, plug-in is overconfident (ignores $v^*$), probit and MC (Markov Chain Monte Carlo) give smoother uncertainty-aware predictions
#
# **EX 4 | PART 6** | probit limit $p(y^*=1|\mathbf{y},\mathbf{x}^*) \to 0.5$ as $v^* \to \infty$ (high uncertainty $\Rightarrow$ uninformative), plug-in and probit yield same decisions (decision boundary at $\mathbf{m}^T\mathbf{x}^* = 0$, denominator $\sqrt{8/\pi + v^*}$ always positive so does not affect sign), uncertainty affects probabilities but not hard classifications

# %% [markdown]
# ### **Week 5:**
#
# [Week 5 notebook](../notebooks/ex5_handout.ipynb)
#
# [Slides 5](../slides/lecture5_handout.pdf)

# %% [markdown]
# **EX 5 | PART 1** | sampling from multivariate Gaussian via Cholesky decomposition $\mathbf{K} = \mathbf{L}\mathbf{L}^T$, transform $\mathbf{f} = \mathbf{L}\mathbf{z} + \mathbf{m}$ where $\mathbf{z} \sim \mathcal{N}(\mathbf{0}, \mathbf{I})$, proof $\mathbb{E}[\mathbf{f}] = \mathbf{m}$ and $\mathbb{V}[\mathbf{f}] = \mathbf{L}\mathbf{I}\mathbf{L}^T = \mathbf{K}$, jitter $\epsilon$ added to diagonal for numerical stability, jitter shifts eigenvalues by $\epsilon$ (proof: $(\mathbf{K}+\epsilon\mathbf{I})\mathbf{v} = (\lambda+\epsilon)\mathbf{v}$), Kronecker delta $\delta(\mathbf{x}_n - \mathbf{x}_m)$
#
# **EX 5 | PART 2** | stationary kernel (depends only on $\tau = \mathbf{x}_n - \mathbf{x}_m$), isotropic kernel (depends only on $\|\tau\|$), squared exponential $k_\text{SE} = \kappa^2\exp(-\|\tau\|^2/2\ell^2)$ (stationary + isotropic + infinitely differentiable), Matérn $\frac{1}{2}$: $\kappa^2\exp(-\|\tau\|/\ell)$ (stationary + isotropic, not differentiable), Matérn $\frac{3}{2}$ (stationary + isotropic, once differentiable), ARD kernel (stationary but not isotropic, separate $\ell_i$ per dimension), linear kernel (neither stationary nor isotropic), pairwise distances via vectorized broadcasting, effect of $\kappa$ (vertical scale/amplitude) and $\ell$ (smoothness/correlation length), SE covariance at distance $d\cdot\ell$: $\exp(-d^2/2)$
#
# **EX 5 | PART 3** | GP prior $\mathbf{f} \sim \mathcal{N}(\mathbf{0}, \mathbf{K})$, joint model $p(\mathbf{y}, \mathbf{f}) = \mathcal{N}(\mathbf{y}|\mathbf{f}, \sigma^2\mathbf{I})\mathcal{N}(\mathbf{f}|\mathbf{0}, \mathbf{K})$, posterior mean $\mu_{f^*} = k_*(K + \sigma^2 I)^{-1}y$, posterior covariance $\Sigma_{f^*} = K_{**} - k_*(K+\sigma^2 I)^{-1}k_*^T$, $C = K + \sigma^2 I$ (noisy kernel matrix), `jnp.linalg.solve` for stability over explicit inversion, posterior predictive for $y^*$ adds $\sigma^2 I$, near data: small $k_*$ gives large posterior variance (reverts to prior), prior vs posterior covariance matrices (dark = constrained by data, bright = uncertain), effect of $\ell$ on smoothness, $\kappa$ on amplitude, $\sigma$ on noise level
#
# **EX 5 | PART 4** | evidence approximation / type II MLE $\hat{\theta} = \arg\max_\theta \ln p(\mathbf{y}|\theta)$, log marginal likelihood $\ln p(\mathbf{y}|\theta) = -\frac{N}{2}\ln(2\pi) - \frac{1}{2}\ln|C| - \frac{1}{2}\mathbf{y}^TC^{-1}\mathbf{y}$, Cholesky-based stable computation (log-determinant via $\sum\ln \text{diag}(L)$, quadratic term via $\|L^{-1}y\|^2$), log-domain reparametrization to enforce $\kappa, \ell, \sigma > 0$, gradient-based optimization via JAX autodiff, cross-validation comparison: $5 \times 10^3 = 5000$ model fits for 3 hyperparameters with 10 values each and 5-fold CV
#
# **EX 5 | PART 5** | bike sharing dataset, log-transform + standardize (zero mean, unit variance), GP regression fit with SE kernel, optimized hyperparameters via marginal likelihood, posterior predictive visualization, heteroskedastic noise concern (constant $\sigma^2$ unrealistic for count data with time-varying patterns), back-transform samples: reverse standardization then $\exp(\cdot)$, log-normal samples in original space

# %% [markdown]
# ### **Week 6:**
#
# [Week 6 notebook](../notebooks/ex6_handout.ipynb)
#
# [Slides 6](../slides/lecture6_handout.pdf)

# %% [markdown]
# **EX 6 | PART 1** | GP classification model $y|f(\mathbf{x}) \sim \text{Ber}[\sigma(f(\mathbf{x}))]$ with $f \sim \mathcal{GP}(0, k)$, joint model $p(\mathbf{y},\mathbf{f}) = \prod_n \text{Ber}(y_n|\sigma(f_n))\mathcal{N}(\mathbf{f}|\mathbf{0},\mathbf{K})$, intractable posterior $p(\mathbf{f}|\mathbf{y})$, 3-step Laplace approach (posterior of $\mathbf{f}$ → posterior of $f^*$ → posterior predictive of $y^*$), difference between $f^* \in \mathbb{R}$ (latent) and $y^* \in \{0,1\}$ (label), inverse link function $\sigma: \mathbb{R} \to (0,1)$
#
# **EX 6 | PART 2** | log joint $\log p(\mathbf{y},\mathbf{f}) = \sum_n \log p(y_n|f_n) - \frac{1}{2}\mathbf{f}^T\mathbf{K}^{-1}\mathbf{f} + \text{const}$, gradient $\nabla_\mathbf{f} = \mathbf{g} - \mathbf{K}^{-1}\mathbf{f}$ where $g_n = y_n - \sigma(f_n)$, Hessian $\nabla^2_\mathbf{f} = -\Lambda - \mathbf{K}^{-1}$, $\Lambda$ diagonal with $\Lambda_{nn} = \sigma(f_n)(1-\sigma(f_n))$, Laplace posterior $q(\mathbf{f}) = \mathcal{N}(\mathbf{f}|\mathbf{m}, \mathbf{S})$ where $\mathbf{m} = \hat{\mathbf{f}}_\text{MAP}$ and $\mathbf{S} = (\mathbf{K}^{-1}+\Lambda)^{-1}$, Woodbury identity $\mathbf{S} = \mathbf{K} - \mathbf{K}\Lambda^{1/2}(\mathbf{I}+\Lambda^{1/2}\mathbf{K}\Lambda^{1/2})^{-1}\Lambda^{1/2}\mathbf{K}$, matrix $\mathbf{B} = \mathbf{I} + \Lambda^{1/2}\mathbf{K}\Lambda^{1/2}$ (eigenvalues $\geq 1$, numerically stable), reparametrization $\mathbf{f} = \mathbf{K}\mathbf{a}$ for stable optimization, first derivative $\frac{\partial}{\partial f_n}\log p(y_n|f_n) = y_n - \sigma(f_n)$, second derivative $= -\sigma(f_n)(1-\sigma(f_n))$
#
# **EX 6 | PART 3** | prior joint $p(f^*, \mathbf{f}) = \mathcal{N}\!\left(\mathbf{0}, \begin{bmatrix}c & \mathbf{k}^T \\ \mathbf{k} & \mathbf{K}\end{bmatrix}\right)$ where $c = k(\mathbf{x}^*,\mathbf{x}^*)$, conditional $p(f^*|\mathbf{f}) = \mathcal{N}(f^*|\mathbf{k}^T\mathbf{K}^{-1}\mathbf{f},\; c - \mathbf{k}^T\mathbf{K}^{-1}\mathbf{k})$ via Gaussian conditioning, approximate posterior $p(f^*|\mathbf{y},\mathbf{x}^*) \approx \mathcal{N}(f^*|\mu_{f^*}, \sigma^2_{f^*})$, posterior mean $\mu_{f^*} = \mathbf{k}^T\mathbf{K}^{-1}\mathbf{m}$, posterior variance $\sigma^2_{f^*} = c - \mathbf{k}^T\mathbf{K}^{-1}(\mathbf{K}-\mathbf{S})\mathbf{K}^{-1}\mathbf{k}$, marginalization over $q(\mathbf{f})$ via linear Gaussian system
#
# **EX 6 | PART 4** | posterior predictive $p(y^*=1|\mathbf{y},\mathbf{x}^*) = \int \sigma(f^*)p(f^*|\mathbf{y},\mathbf{x}^*)df^*$, probit approximation $\sigma(f^*) \approx \Phi(f^*\sqrt{\pi/8})$, closed form $p(y^*=1|\mathbf{y},\mathbf{x}^*) \approx \Phi\!\left(\frac{\mu_{f^*}}{\sqrt{8/\pi + \sigma^2_{f^*}}}\right)$, high $\sigma^2_{f^*}$ (epistemic) $\to p \to 0.5$, aleatoric uncertainty near decision boundary, GP reverts to $p=0.5$ outside data support vs NN stays confident, NN vs GP comparison (inside and outside data support), effect of $\alpha$ on NN regularization
#
# **EX 6 | PART 5** | 2D GP classification on MNIST digits, posterior mean of $f^*$ (continuous latent), posterior variance of $f^*$ (epistemic, increases away from data), posterior predictive $p(y^*=1|\mathbf{y})$ (discrete label probability), $\mathbf{m}$ in Laplace = MAP estimate of latent function at training points, GP uncertainty $\to 0.5$ outside data support (epistemic dominates), NN maintains sharp decision boundary everywhere (overconfident), training/test error via thresholding at $p=0.5$

# %% [markdown]
# ### **Week 7:**
#
# [Week 7 notebook](../notebooks/ex7_handout.ipynb)
#
# [Slides 7](../slides/lecture7_handout.pdf)

# %% [markdown]
# **EX 7 | PART 1** | multi-class classification, categorical distribution $\text{Cat}(y_n|\text{softmax}(\mathbf{f}_n))$, softmax $\text{softmax}(\mathbf{f}_n)_i = \exp(f_{n,i})/\sum_j \exp(f_{n,j})$, $K$ linear models $f_{n,i} = \mathbf{w}_i^T\phi(\mathbf{x}_n)$, weight matrix $\mathbf{W} \in \mathbb{R}^{K\times D}$, i.i.d. Gaussian prior $\mathcal{N}(\mathbf{w}_i|\mathbf{0}, \alpha^{-1}\mathbf{I})$, flattened parameters $\mathbf{w}_\text{flat} \in \mathbb{R}^{K\cdot D}$, Laplace approximation $q(\mathbf{w}_\text{flat}) = \mathcal{N}(\mathbf{m}, \mathbf{S})$ via JAX autodiff (Hessian), one-hot encoding, log-likelihood $\sum_n \sum_k y_{n,k}\log\text{softmax}(\mathbf{f}_n)_k$, numerical stability via subtracting max before softmax, Monte Carlo posterior predictive $\boldsymbol{\pi}_k \approx \frac{1}{S}\sum_j \text{softmax}(\mathbf{f}_*^{(j)})_k$, connection to last layer of neural network, softmax name intuition (highest latent $f$ gets highest probability)
#
# **EX 7 | PART 2** | predictive entropy $\mathcal{H}[p(y^*|\mathbf{y},\mathbf{x}^*)] = -\sum_k \pi_k \log \pi_k$, confidence $\mathcal{C} = \max_k p(y^*=k|\mathbf{y},\mathbf{x}^*)$, high confidence $\leftrightarrow$ low entropy, total uncertainty $\mathcal{H}_\text{total} = \mathcal{H}[\text{Cat}(y^*|\boldsymbol{\pi})]$, aleatoric uncertainty $\mathcal{H}_\text{aleatoric} = \frac{1}{S}\sum_i \mathcal{H}[\text{Cat}(y^*|\boldsymbol{\pi}^{(i)})]$ (expected entropy of likelihood over posterior samples), epistemic uncertainty $\mathcal{H}_\text{epistemic} = \mathcal{H}_\text{total} - \mathcal{H}_\text{aleatoric}$, aleatoric dominates within data support (class overlap), epistemic dominates outside data support (no data), non-linear features increase epistemic uncertainty, upper bound $\ln K$ (uniform distribution)
#
# **EX 7 | PART 3** | Bayesian decision theory, utility function $\mathcal{U}(y^*, \hat{y})$, expected utility $\mathbb{E}_{p(y^*|\mathbf{y},\mathbf{x}^*)}[\mathcal{U}(y^*,\hat{y}=k)] = \sum_k \pi_k \mathcal{U}(k,\hat{y})$, optimal decision $\hat{y}^* = \arg\max_k \mathbb{E}[\mathcal{U}]$, 0/1-utility $\Rightarrow$ pick class with highest posterior probability, scaling utility by positive constant does not change decisions, negative off-diagonal utility shrinks decision region for penalized class, $U_{ij}=U_{ji}=1$ merges decision regions of classes $i$ and $j$, utility matrix shape $K\times K$, expected utility computation as matrix product $\hat{\mathbf{U}} = \hat{\boldsymbol{\pi}} \mathbf{U}$
#
# **EX 7 | PART 4** | transfer learning, ResNet18 as feature extractor (512-dim features), PCA dimensionality reduction for visualization, Linnaeus 5 dataset (dogs, birds, flowers, berries), Bayesian linear softmax on image features, accuracy on train/test, confidence and entropy maps (uncertain near class boundaries), average confidence vs accuracy comparison
#
# **EX 7 | PART 5** | reject option, reject threshold $p_\text{reject}$, reject region = low-confidence region, reject region $\equiv$ high-entropy region, accuracy on kept samples vs rejected samples (kept $>$ rejected), fraction rejected grows with threshold, custom utility (higher utility for specific class $\Rightarrow$ expanded decision region for that class)
#
# **EX 7 | PART 6** | model calibration, confidence histogram, reliability plot (calibration plot): $\text{acc}(\mathcal{B}_b)$ vs $\text{conf}(\mathcal{B}_b)$ per bin, expected calibration error $\text{ECE} = \sum_b \frac{|\mathcal{B}_b|}{M}|\text{acc}(\mathcal{B}_b) - \text{conf}(\mathcal{B}_b)|$, perfectly calibrated: diagonal reliability plot, overconfident: curve below diagonal, underconfident: curve above diagonal, effect of $\alpha$: large $\alpha$ (strong prior) $\Rightarrow$ underconfident, small $\alpha$ $\Rightarrow$ overconfident, ECE not a proper scoring rule (must combine with accuracy/ELPD)

# %% [markdown]
# ### **Week 8:**
#
# [Week 8 notebook](../notebooks/ex8_handout.ipynb)
#
# [Slides 8](../slides/lecture8_handout.pdf)

# %% [markdown]
# **EX 8 | PART 1** | ancestral sampling, joint distribution via product rule $p(x_1,x_2,x_3,x_4) = p(x_1)p(x_2)p(x_3|x_1,x_2)p(x_4|x_3)$, sample sequentially following causal order, marginal mean/variance/95% interval via sample statistics, use ancestral sampling for posterior predictive after MCMC, Markov Chain Monte Carlo, (sample $p(x_1|\mathbf{y})$ then propagate forward)
#
# **EX 8 | PART 2** | Metropolis-Hastings algorithm, target distribution $p_t(\theta)$ (only need up to constant), Gaussian proposal $q(\theta^*|\theta^{k-1}) = \mathcal{N}(\theta^*|\theta^{k-1}, \tau^2\mathbf{I})$, acceptance ratio $r_k = \frac{p_t(\theta^*)q(\theta^{k-1}|\theta^*)}{p_t(\theta^{k-1})q(\theta^*|\theta^{k-1})}$, acceptance probability $A_k = \min(1, \exp[\log r_k])$, accept if $u_k < A_k$ where $u_k \sim \mathcal{U}(0,1)$, symmetric Gaussian proposal $\Rightarrow$ proposal ratio cancels ($q(\theta^{k-1}|\theta^*) = q(\theta^*|\theta^{k-1})$), normalizing constant $p(\mathbf{y})$ cancels in ratio (key for Bayesian inference), if $p_t(\theta^*) > p_t(\theta^{k-1})$ then $A_k = 1$ (always accept uphill moves), log-domain computation for numerical stability
#
# **EX 8 | PART 3** | trace plots (detect non-convergence), warm-up/burn-in phase (discard early biased samples), step-size $\tau$ effect: small $\tau$ $\Rightarrow$ high acceptance but slow mixing, large $\tau$ $\Rightarrow$ low acceptance and poor coverage, acceptance rate $\approx 0.234$ optimal for high-dim (rule of thumb), correlated targets (high $\rho$) $\Rightarrow$ low acceptance and poor mixing with isotropic proposal, Laplace distribution $\propto \exp(-|\theta-3|)$, mixture of Laplace, skew-normal $2\phi(\theta)\Phi(5\theta)$, computing $p(\theta > 1)$ from samples
#
# **EX 8 | PART 4** | Poisson regression for count data $y_n|\mu_n \sim \text{Poisson}(\mu_n)$, log link $\mu_n = \exp(f_n)$ where $f_n = \mathbf{w}^T\mathbf{x}_n$, Gaussian prior $\mathbf{w}|\kappa \sim \mathcal{N}(\mathbf{0}, \kappa^2\mathbf{I})$, half-normal hyperprior $\kappa \sim \mathcal{N}_+(0,1)$ (enforces $\kappa > 0$, prevents overfitting), fully Bayesian inference (hyperprior instead of marginal likelihood optimization), joint $p(\mathbf{y},\mathbf{w},\kappa) = \prod_n p(y_n|\mathbf{w})p(\mathbf{w}|\kappa)p(\kappa)$, flattened parameter $\theta = [w_0, w_1, \kappa]$, return $-\infty$ for $\kappa < 0$, posterior samples via MH then ancestral sampling for $f^* \to \mu^* = \exp(f^*) \to y^* \sim \text{Poisson}(\mu^*)$, prior vs posterior of $\kappa$ and $\mathbf{w}$ (data more informative about $\mathbf{w}$ than $\kappa$)
#
# **EX 8 | PART 5** | importance sampling, importance weights $w^{(i)} = p(z^{(i)})/q(z^{(i)})$, estimator $\hat{f} = \frac{1}{S}\sum_i w^{(i)}f(z^{(i)})$ where $z^{(i)} \sim q$, unbiased estimator, skew-normal target $p(z) = 2\phi(z)\Phi(5z)$ with analytical mean $\approx 0.7824$, proposal alignment critical: $q_1 = \mathcal{N}(1,1)$ (overlaps with $p$) vs $q_2 = \mathcal{N}(4,1)$ (misaligned, high variance weights, poor estimate), variance of estimator decreases with $S$, misaligned proposal $\Rightarrow$ high variance even for large $S$

# %% [markdown]
# ### **Week 9:**
#
# [Week 9 notebook](../notebooks/ex9_handout.ipynb)
#
# [Slides 9](../slides/lecture9_handout.pdf)

# %% [markdown]
# **EX 9 | PART 1** | Hamiltonian Monte Carlo (HMC), phase-space $(\boldsymbol{\theta}, \boldsymbol{\nu})$, potential energy $E(\boldsymbol{\theta}) = -\log p_t(\boldsymbol{\theta})$, kinetic energy $K(\boldsymbol{\nu}) = -\log p(\boldsymbol{\nu}) = \frac{1}{2}\|\boldsymbol{\nu}\|^2 + \text{const}$, Hamiltonian $H = E + K$, momentum $\boldsymbol{\nu} \sim \mathcal{N}(\mathbf{0}, \mathbf{I})$, Hamiltonian conservation (exact dynamics), pen-and-paper: $\nabla_\theta E(\theta) = 2(\theta-1)$ for $\mathcal{N}(\theta|1, \frac{1}{2})$, acceptance probability $a_k = \min(1, \exp[-H(\theta^*,\nu^*) + H(\theta_{k-1},\nu_{k-1})])$, uphill move always accepted ($A_k = 1$)
#
# **EX 9 | PART 2** | leapfrog integrator, half-step momentum $\boldsymbol{\nu}_{j+1/2} = \boldsymbol{\nu}_j - \frac{\eta}{2}\nabla_\theta E(\boldsymbol{\theta}_j)$, full-step position $\boldsymbol{\theta}_{j+1} = \boldsymbol{\theta}_j + \eta\boldsymbol{\nu}_{j+1/2}$, half-step momentum $\boldsymbol{\nu}_{j+1} = \boldsymbol{\nu}_{j+1/2} - \frac{\eta}{2}\nabla_\theta E(\boldsymbol{\theta}_{j+1})$, step-size $\eta$ controls discretization error, Hamiltonian approximately conserved by leapfrog, large $\eta$ $\Rightarrow$ large discretization error $\Rightarrow$ low acceptance, reversibility (negate momentum and re-run returns to start), `jit` compilation for speed, `grad` via JAX autodiff
#
# **EX 9 | PART 3** | HMC algorithm: (1) sample $\boldsymbol{\nu}_{k-1} \sim \mathcal{N}(\mathbf{0},\mathbf{I})$, (2) leapfrog $L$ steps to get $(\theta^*,\nu^*)$, (3) MH accept/reject on $\Delta H$, multiple chains from different initialisations for convergence assessment, $\hat{R}$ statistic $\hat{R}^2 = \frac{S-1}{S} + \frac{B}{SW}$ (between-chain vs within-chain variance), $\hat{R} \approx 1$ $\Rightarrow$ converged, threshold $\hat{R} < 1.1$, effective sample size $S_\text{eff} = S/(1 + 2\sum_t \rho_t)$ (accounts for autocorrelation), warm-up discarded before computing diagnostics, chains merged after diagnostics
#
# **EX 9 | PART 4** | heteroscedastic regression model, homoscedastic assumption violation (variance grows with $x$), softplus link $\sigma^2(x_n) = \log(1+e^{v_0+v_1 x_n})$ ensures $\sigma^2 > 0$, model $y_n|x_n,\mathbf{w},\mathbf{v} \sim \mathcal{N}(f(x_n), \sigma^2(x_n))$, parameters $\boldsymbol{\theta} = [\mathbf{w}, \mathbf{v}] \in \mathbb{R}^4$, Gaussian prior $\mathcal{N}(\mathbf{0}, \tau^2\mathbf{I})$ with $\tau^2=3$, log joint = log prior ($\mathbf{w}$) + log prior ($\mathbf{v}$) + $\sum_n$ log likelihood, trace plots for mixing assessment, $\hat{R}$ and ESS post warm-up, small $\eta = 10^{-4}$ $\Rightarrow$ tiny steps, high autocorrelation, low ESS, slow mixing, posterior predictive via ancestral sampling: $f^{(s)}(x^*) \to \sigma^{2(s)}(x^*) \to y^{(s)} \sim \mathcal{N}(f^{(s)},\sigma^{2(s)})$, merge chains before inference, thinning to reduce autocorrelation
#
# **EX 9 | PART 5** | Bayesian neural network via HMC, two-layer MLP with tanh activations, `ravel_pytree` to flatten parameter dict to vector, softplus output for $f$ and $\sigma^2$, multimodal posterior (chains may not mix across modes), linear vs NN model comparison (linear sufficient here, NN overkill with 244 points), student-t likelihood for robustness (heavier tails, only change `log_joint`), formal model selection: $k$-fold CV, log predictive density $\log p(y^*|\mathbf{y},x^*) \approx \frac{1}{S}\sum_s \log p(y^*|\theta^{(s)},x^*)$ as primary metric (rewards calibration), RMSE as secondary, HMC advantage: swap likelihood without redesigning sampler

# %% [markdown]
# ### **Week 10:**
#
# [Week 10 notebook](../notebooks/ex10_handout.ipynb)
#
# [Slides 10](../slides/lecture10_handout.pdf)

# %% [markdown]
# **EX 10 | PART 1** | variational inference, KL divergence $\text{KL}[q\|p]$, variational family $\mathcal{Q}$, optimal approximation $q^* = \arg\min_{q\in\mathcal{Q}}\text{KL}[q\|p]$, mean-field factorization $q(\mu,\tau) = q(\mu)q(\tau)$, CAVI update $\ln q^*(\mu) = \mathbb{E}_{q(\tau)}[\ln p(\mathcal{D},\mu,\tau)] + \text{const}$, Gamma prior $\text{Gamma}(\tau|a_0,b_0)$ for precision, Gaussian prior $\mathcal{N}(\mu|\mu_0,(\lambda_0\tau)^{-1})$ for mean, matching log-joint coefficients to identify $q^*(\mu) = \mathcal{N}(\mu|m,v)$ (quadratic in $\mu$ $\Rightarrow$ Gaussian), $q^*(\tau) = \text{Gamma}(\tau|a,b)$ (linear $\ln\tau$ and linear $\tau$ terms), variational parameters $m = \frac{N\bar{x}+\lambda_0\mu_0}{N+\lambda_0}$, $v = \frac{1}{(N+\lambda_0)\mathbb{E}[\tau]}$, $a = a_0 + \frac{N+1}{2}$, $\mathbb{E}[\tau] = a/b$ for Gamma, CAVI iterates until convergence, marginals in mean-field equal the factors directly
#
# **EX 10 | PART 2** | Gaussian Mixture Model (GMM) $p(\mathbf{x}_n|\pi,\mathbf{m},\Lambda) = \sum_k \pi_k \mathcal{N}(\mathbf{x}_n|\mathbf{m}_k,\Lambda_k^{-1})$, latent variable formulation $z_n \sim \text{Categorical}(\pi)$, one-hot $z_n$ selects component, marginalization over $z_n$ recovers mixture, Dirichlet prior $\pi \sim \text{Dir}(\alpha_0)$ (distribution over distributions, samples are valid probability vectors), Wishart prior $\Lambda_k \sim \mathcal{W}(W_0,\nu_0)$ (distribution over positive definite matrices), Normal-Wishart prior $\mu_k|\Lambda_k \sim \mathcal{N}(m_0,(\beta_0\Lambda_k)^{-1})$, ancestral sampling order: $\pi \to \Lambda_k \to \mu_k \to z_n \to x_n$, $\alpha_0$ small $\Rightarrow$ sparse weights (few clusters dominate), $\alpha_0$ large $\Rightarrow$ uniform weights, $\beta_0$ small $\Rightarrow$ cluster means spread far from $m_0$, MLE singularities avoided by Bayesian priors
#
# **EX 10 | PART 3** | ELBO $\mathcal{L}[q] = \mathbb{E}_q[\ln p(X,Z,\mu,\Lambda,\pi)] - \mathbb{E}_q[\ln q(Z,\mu,\Lambda,\pi)]$, $\ln p(X) = \text{KL}[q\|p] + \mathcal{L}[q]$ (ELBO is lower bound since KL $\geq 0$), maximizing ELBO $\equiv$ minimizing KL (since $\ln p(X)$ constant wrt $q$), factorization $q(Z)q(\pi)q(\mu,\Lambda)$, responsibilities $r_{nk} = q(z_{nk})$ (soft cluster assignments), effective cluster size $N_k = \sum_n r_{nk}$, posterior mixing weight $\mathbb{E}[\pi_k|X] = \frac{\alpha_0+N_k}{K\alpha_0+N}$, posterior mean $m_k = \frac{1}{\beta_k}(\beta_0 m_0 + N_k\bar{x}_k)$ (convex combination: $\rho = N_k/\beta_k$), $\beta_k = \beta_0 + N_k$, $\nu_k = \nu_0 + N_k + 1$, monitor ELBO for convergence, $K^N$ configurations makes exact inference intractable
#
# **EX 10 | PART 4** | automatic cluster pruning with small $\alpha_0$ (unnecessary clusters get $\pi_k \approx 0$), label switching (cluster labels arbitrary, permutation-invariant), only relative cluster membership questions are meaningful (not "which cluster number"), model selection via test log predictive density $p(x^*|X)$ across $K$ values, ELBO increases with $K$ but test LPD identifies optimal $K$, image clustering with ResNet18 features + PCA, $\alpha_0 = 10^{-3}$ encourages sparse solution, log predictive density $p(x^*|X)$ evaluated via Bishop eq. (10.80), cluster visualization to assess semantic coherence

# %% [markdown]
# ### **Week 11:**
#
# [Week 11 notebook](../notebooks/ex11_handout.ipynb)
#
# [Slides 11](../slides/lecture11_handout.pdf)

# %% [markdown]
# **EX 11 | PART 1** | KL divergence $\text{KL}[q\|p] = \frac{1}{2}[\text{tr}(\mathbf{V}^{-1}\hat{\mathbf{V}}) + (\mathbf{m}-\hat{\mathbf{m}})^T\mathbf{V}^{-1}(\mathbf{m}-\hat{\mathbf{m}}) - D + \log\frac{|\mathbf{V}^{-1}|}{|\hat{\mathbf{V}}|}]$, mean-field family $q(\mathbf{w}) = \prod_i \mathcal{N}(w_i|m_i,v_i)$ (diagonal $\hat{\mathbf{V}}$), target $p$ belongs to family only if $\mathbf{V}$ diagonal, optimal mean $\hat{\mathbf{m}} = \mathbf{m}$, optimal variance $\hat{\mathbf{V}}_{ii} = \frac{1}{(\mathbf{V}^{-1})_{ii}}$ (reciprocal of precision diagonal), mean-field underestimates marginal variances when $\rho \neq 0$ (KL$[q\|p]$ is mass-covering $\Rightarrow$ tends to underestimate variance), $\mathbb{E}_q[w_iw_j] = m_im_j$ for $i\neq j$ (independence), $\mathbb{E}_q[w_i^2] = m_i^2 + v_i$
#
# **EX 11 | PART 2** | ELBO $\mathcal{L}[q] = \mathbb{E}_{q(\mathbf{w})}[\log p(\mathbf{y},\mathbf{w})] - \mathbb{E}_{q(\mathbf{w})}[\log q(\mathbf{w})]$, entropy of mean-field Gaussian $\mathcal{H}[q] = \frac{1}{2}\sum_i \log(2e\pi v_i)$, MC estimate of expected log joint $\approx \frac{1}{S}\sum_s \log p(\mathbf{y},\mathbf{w}^s)$, reparametrization trick $\mathbf{w}_\epsilon = \mathbf{m} + \mathbf{s}\circ\boldsymbol{\epsilon}$ where $\boldsymbol{\epsilon}\sim\mathcal{N}(\mathbf{0},\mathbf{I})$ (separates randomness from parameters so gradient flows through $\mathbf{m}$ and $\mathbf{s}$), minibatching: scale likelihood term by $N/M$, unbiased estimator, variational parameters $\lambda = \{\mathbf{m}, \log\mathbf{v}\}$ (log-domain for positivity), Adam optimizer, stochastic gradients
#
# **EX 11 | PART 3** | analytical ELBO for linear Gaussian: expected log likelihood $= \sum_n \log\mathcal{N}(y_n|\mathbf{m}^T\mathbf{x}_n,\sigma^2) - \frac{1}{2\sigma^2}\sum_i v_i \sum_n x_{ni}^2$, expected log prior $= \sum_i \log\mathcal{N}(m_i|0,\kappa^2) - \frac{1}{2\kappa^2}\sum_i v_i$, full-rank family would add $\Sigma_{ij}$ cross terms (no longer simplifies via independence), exact posterior mean matches variational mean, variational variance underestimates exact posterior variance (mean-field cannot capture correlations)
#
# **EX 11 | PART 4** | BBVI vs VI comparison: VI smooth ELBO (analytic gradient), BBVI noisy ELBO (stochastic gradient), both converge to same mean, BBVI flexible (swap likelihood with no re-derivation), more MC samples $\Rightarrow$ smoother optimization, smaller batch $\Rightarrow$ noisier but cheaper per iteration, batch estimator unbiased, true weights $\neq$ posterior mean (prior regularization + noise), black-box means only `log_prior` and `log_lik` needed
#
# **EX 11 | PART 5** | spam/ham classification, FastText embeddings (300-dim $\to$ 15-dim PCA), sigmoid likelihood $\text{Ber}(y|\sigma(\mathbf{w}^T\mathbf{x}))$, probit likelihood $\text{Ber}(y|\Phi(\mathbf{w}^T\mathbf{x}))$, robust likelihood $p(y|\mathbf{w},\mathbf{x}) = (1-\epsilon)\text{Ber}(y|\sigma(f)) + \epsilon\text{Ber}(y|\sigma(-f))$ (marginalizes over mislabelling indicator $e_i \sim \text{Ber}(\epsilon)$), probit penalizes outliers most severely (log likelihood $\to -55$), sigmoid moderate, robust bounded floor $\approx -3$ (insensitive to confident errors), outlier robustness $\propto$ tail heaviness of likelihood
#
# **EX 11 | PART 6** | logsumexp trick for robust log likelihood (numerical stability), predictive $p(y^*=1|\mathbf{y},\mathbf{x}^*) \approx \frac{1}{S}\sum_s \sigma(\mathbf{w}^{(s)T}\mathbf{x}^*)$, accuracy and F1 score, smoothed ELBO for convergence diagnosis, $\epsilon$ could be learned via ELBO optimization (type II ML) or given Beta prior, augmenting variational family for $\epsilon$: change of variable $\tilde{\epsilon} = \sigma^{-1}(\epsilon) \in \mathbb{R}$ then impose Gaussian (support mismatch issue), alternative: $q(\mathbf{w},\epsilon) = \prod_i\mathcal{N}(w_i)\cdot\text{Beta}(\epsilon|\tilde{a},\tilde{b})$

# %% [markdown]
# ### **Week 12:**
#
# [Week 12 notebook](../notebooks/ex12_handout.ipynb)
#
# [Slides 12](../slides/lecture12_handout.pdf)

# %% [markdown]
# **EX 12 | PART 1** | Bayesian deep learning, heteroscedastic model $p(y_n|\mathbf{w},\mathbf{x}_n) = \mathcal{N}(y_n|\mu_\mathbf{w}(\mathbf{x}_n), \sigma^2_\mathbf{w}(\mathbf{x}_n))$, NN outputs $\mu_\mathbf{w}(\mathbf{x}) = f_1(\mathbf{x}|\mathbf{w})$ and $\log\sigma^2_\mathbf{w}(\mathbf{x}) = f_2(\mathbf{x}|\mathbf{w})$ (softplus ensures $\sigma^2>0$), two-hidden-layer MLP with tanh, isotropic Gaussian prior $\mathcal{N}(\mathbf{w}|\mathbf{0},\alpha^{-1}\mathbf{I})$, posterior predictive $p(y^*|\mathbf{y},\mathbf{x}^*) \approx \frac{1}{S}\sum_i p(y^*|\mathbf{w}^{(i)},\mathbf{x}^*)$, MAP $\equiv$ plugin approximation ($S=1$, $q_\text{MAP} = \delta(\mathbf{w}-\mathbf{w}_\text{MAP})$), Deep Ensemble $q_\text{DE}(\mathbf{w}) = \frac{1}{S}\sum_i \delta(\mathbf{w}-\mathbf{w}^{(i)})$ (train $S$ models from different seeds), Last Layer Laplace Approximation (LLLA): Laplace only on $\mathbf{w}_L = \{\mathbf{W}_2,\mathbf{b}_2\}$ (cheaper Hessian, post-hoc applicable), LPD $= \frac{1}{M}\sum_m \log[\frac{1}{S}\sum_i \mathcal{N}(y^*_m|f_1^{(i)},e^{f_2^{(i)}})]$, logsumexp for numerical stability
#
# **EX 12 | PART 2** | homoscedastic inappropriate when variance grows with input, heteroscedastic fit: narrow CI for $x<0$, wide CI for $x>5$, log likelihood $= \sum_n \log\mathcal{N}(y_n|f_{n,1}, e^{f_{n,2}})$, MAP LPD computed via plugin ($S=1$)
#
# **EX 12 | PART 3** | LLLA implementation: (1) compute $\mathbf{z}_2 = f_{1:L-1}(\mathbf{x})$ fixed, (2) Hessian of log joint wrt $\mathbf{w}_L$ only: $H = H_\text{loglik} + \alpha I$, (3) $S_\text{LLLA} = H^{-1}$, (4) sample $\mathbf{w}_L^{(i)} \sim \mathcal{N}(\mathbf{w}_\text{MAP,L}, S_\text{LLLA})$, (5) propagate through last layer, `ravel_pytree` to flatten/unflatten nested params, LLLA wider CI than MAP (captures epistemic uncertainty in last layer), MAP overconfident outside data, LLLA uncertainty grows away from data, aleatoric only in plot 1 (MAP), epistemic only in plot 2 ($f_1$ samples), both in plots 3 and 4
#
# **EX 12 | PART 4** | Deep Ensemble: 10 models trained from different seeds, samples of $f_1(x)$ diverge outside training data (epistemic grows), LPD via `logsumexp` trick, DE $>$ LLLA $>$ MAP in test LPD, LPD improves with ensemble size (diminishing returns), MAP large train-test gap (overfitting), DE explores multiple posterior modes
#
# **EX 12 | PART 5** | Concrete dataset ($N=1030$, $D=8$), standardize inputs, 90/10 train-test split, MAP worst (large train-test LPD gap $\Rightarrow$ overconfident), LLLA better (last-layer epistemic uncertainty), DE best (diverse modes, most robust), LPD vs ensemble size: improvement levels off after $\sim5$ models, MAP as horizontal baseline
