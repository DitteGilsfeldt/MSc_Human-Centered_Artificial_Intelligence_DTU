# %% [markdown]
# # Login fra terminalen i hpc

# %% [markdown]
# ssh s210666@login.hpc.dtu.dk

# %% [markdown]
# linuxsh

# %% [markdown]
# cd ind her fra

# %% [markdown]
# # log ind fra terminalen på egen computer og upload

# %% [markdown]
# cd ind

# %% [markdown]
# scp [file path] s210666@login.hpc.dtu.dk:/zhome/50/6/160655/Documents/02613_PyHPC/[file path]

# %% [markdown]
# # kør den uploadet fil

# %% [markdown]
# ### Run file on HPC

# %% [markdown]
# bsub < [File path]

# %% [markdown]
# ### Download output files

# %% [markdown]
# scp s210666@login.hpc.dtu.dk:/zhome/50/6/160655/Documents/02613_PyHPC/[File path] .
