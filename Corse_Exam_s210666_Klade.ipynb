# %% [markdown]
# # **Information**
# ---

# %% [markdown]
# **Dato:**
#
# **Course** \
# **Course number:**
#
# **Study number** s210666\
# **Table number**

# %% [markdown]
# # **Part 1**
# ---

# %% [markdown]
# ## **Question 1.1**

# %% [markdown]
# ## **Question 1.2**

# %% [markdown]
# ## **Question 1.3**

# %% [markdown]
# ## **Question 1.4**

# %% [markdown]
# # **Part 2**
# ---

# %% [markdown]
# ## **Question 2.1**

# %% [markdown]
# ## **Question 2.2**

# %% [markdown]
# ## **Question 2.3**

# %% [markdown]
# ## **Question 2.4**

# %% [markdown]
# # **Part 3**
# ---

# %% [markdown]
# ## **Question 3.1**

# %% [markdown]
# ## **Question 3.2**

# %% [markdown]
# ## **Question 3.3**

# %% [markdown]
# ## **Question 3.4**

# %% [markdown]
# # **Part 4**
# ---

# %% [markdown]
# ## **Question 4.1**

# %% [markdown]
# ## **Question 4.2**

# %% [markdown]
# ## **Question 4.3**

# %% [markdown]
# ## **Question 4.4**

# %% [markdown]
# # **Part 5**
# ---

# %% [markdown]
# ## **Question 5.1**

# %% [markdown]
# ## **Question 5.2**

# %% [markdown]
# ## **Question 5.3**

# %% [markdown]
# ## **Question 5.4**
