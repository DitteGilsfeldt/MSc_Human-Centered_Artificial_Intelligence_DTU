# %% [markdown]
# # **Information**
# ---

# %% [markdown]
# **Dato:**
#
# **Course** \
# **Course number:**
#
# **Study number** s210666\
# **Table number**

# %% [markdown]
# # **Opgave 1**
# ---

# %% [markdown]
# ## **1.**

# %% [markdown]
# ## **2.**

# %% [markdown]
# ## **3.**

# %% [markdown]
# ## **4.**

# %% [markdown]
# # **Opgave 2**
# ---

# %% [markdown]
# ## **1.**

# %% [markdown]
# ## **2.**

# %% [markdown]
# ## **3.**

# %% [markdown]
# ## **4.**

# %% [markdown]
# # **Opgave 3**
# ---

# %% [markdown]
# ## **1.**

# %% [markdown]
# ## **2.**

# %% [markdown]
# ## **3.**

# %% [markdown]
# ## **4.**

# %% [markdown]
# # **Opgave 4**
# ---

# %% [markdown]
# ## **1.**

# %% [markdown]
# ## **2.**

# %% [markdown]
# ## **3.**

# %% [markdown]
# ## **4.**
